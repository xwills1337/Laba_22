# %% [markdown]
# <a href="https://colab.research.google.com/github/xwills1337/Laba_22/blob/master/%D1%81%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Случайный массив

# %%
sort_bubble= pd.Series({1000 : 499500, 2000 : 1999000, 3000 : 4498500, 4000 : 7998000, 5000 : 12497500, 6000 : 17997000, 7000 : 24496500, 8000 : 31996000, 9000 : 40495500, 10000: 49995000, 25000: 312487500, 50000: 1249975000, 100000: 4999950000})
plt.plot(sort_bubble)
plt.title("число сравнений в сортировке пузырьком")
plt.show()

# %%
sort_bubble= pd.Series({1000 : 249847, 2000 : 996912, 3000 : 2245186, 4000 : 3991326, 5000 : 6236955, 6000 : 8983846, 7000 : 12222712, 8000 : 15969105, 9000 : 24965942, 10000: 24965942, 25000: 156040811, 50000: 659547124, 100000: 2655719412})
plt.plot(sort_bubble)
plt.title("число копирований в сортировке пузырьком")
plt.show()

# %%
sort_shell= pd.Series({1000 : 15059, 2000 : 36026, 3000 : 58240, 4000 : 83601, 5000 : 111126, 6000 : 138122, 7000 : 162103, 8000 : 196010, 9000 : 217279, 10000: 253489, 25000: 767977, 50000: 1726520, 100000: 3916051})
plt.plot(sort_shell)
plt.title("число сравнений в сортировке Шелла")
plt.show()

# %%
sort_shell= pd.Series({1000 : 7570, 2000 : 19032, 3000 : 29785, 4000 : 45608, 5000 : 58691, 6000 : 75166, 7000 : 88737, 8000 : 112017, 9000 : 113884, 10000: 138589, 25000: 455910, 50000: 1051917, 100000: 2466495})
plt.plot(sort_shell)
plt.title("число копирований в сортировке Шелла")
plt.show()

# %%
sort_pyramid= pd.Series({1000 : 11685, 2000 : 26365, 3000 : 42125, 4000 : 58733, 5000 : 75704, 6000 : 93244, 7000 : 111094, 8000 : 129451, 9000 : 147774, 10000: 166391, 25000: 465855, 50000: 1006651, 100000: 2163146})
plt.plot(sort_pyramid)
plt.title("число сравнений в сортировке пирамидальной")
plt.show()

# %%
sort_pyramid= pd.Series({1000 : 9081, 2000 : 20160, 3000 : 32083, 4000 : 44320, 5000 : 57111, 6000 : 70155, 7000 : 83350, 8000 : 96631, 9000 : 110318, 10000: 124208, 25000: 343757, 50000: 737512, 100000: 1574916})
plt.plot(sort_pyramid)
plt.title("число копирований в сортировке пирамидальной")
plt.show()

# %% [markdown]
# отсортированный массив

# %%
sort_bubble= pd.Series({1000 : 499500, 2000 : 1999000, 3000 : 4498500, 4000 : 7998000, 5000 : 12497500, 6000 : 17997000, 7000 : 24496500, 8000 : 31996000, 9000 : 40495500, 10000: 49995000, 25000: 312487500, 50000: 1249975000, 100000: 4999950000})
plt.plot(sort_bubble)
plt.title("число сравнений в сортировке пузырьком")
plt.show()

# %%
sort_bubble= pd.Series({1000 : 0, 2000 : 0, 3000 : 0, 4000 : 0, 5000 : 0, 6000 : 0, 7000 : 0, 8000 : 0, 9000 : 0, 10000: 0, 25000: 0, 50000: 0, 100000: 0})
plt.plot(sort_bubble)
plt.title("число копирований в сортировке пузырьком")
plt.show()

# %%
sort_shell= pd.Series({1000 : 8006, 2000 : 18006, 3000 : 30007, 4000 : 40006, 5000 : 55005, 6000 : 66007, 7000 : 77007, 8000 : 88006, 9000 : 108005, 10000: 120005, 25000: 325006, 50000: 700006, 100000: 1500006})
plt.plot(sort_shell)
plt.title("число сравнений в сортировке Шелла")
plt.show()

# %%
sort_shell= pd.Series({1000 : 0, 2000 : 0, 3000 : 0, 4000 : 0, 5000 : 0, 6000 : 0, 7000 : 0, 8000 : 0, 9000 : 0, 10000: 0, 25000: 0, 50000: 0, 100000: 0})
plt.plot(sort_shell)
plt.title("число копирований в сортировке Шелла")
plt.show()

# %%
sort_pyramid= pd.Series({1000 : 12963, 2000 : 28850, 3000 : 46279, 4000 : 64514, 5000 : 82690, 6000 : 101889, 7000 : 121200, 8000 : 141300, 9000 : 160710, 10000: 180584, 25000: 499420, 50000: 1074836, 100000: 2303177})
plt.plot(sort_pyramid)
plt.title("число сравнений в сортировке пирамидальной")
plt.show()

# %%
sort_pyramid= pd.Series({1000 : 9709, 2000 : 21301, 3000 : 34253, 4000 : 47143, 5000 : 60933, 6000 : 74829, 7000 : 88765, 8000 : 102639, 9000 : 117223, 10000: 131957, 25000: 361455, 50000: 773305, 100000: 1650855})
plt.plot(sort_pyramid)
plt.title("число копирований в сортировке пирамидальной")
plt.show()

# %% [markdown]
# отсортированный массив в обратном порядке

# %%
sort_bubble= pd.Series({1000 : 499500, 2000 : 1999000, 3000 : 4498500, 4000 : 7998000, 5000 : 12497500, 6000 : 17997000, 7000 : 24496500, 8000 : 31996000, 9000 : 40495500, 10000: 49995000, 25000: 312487500, 50000: 1249975000, 100000: 4999950000})
plt.plot(sort_bubble)
plt.title("число сравнений в сортировке пузырьком")
plt.show()

# %%
sort_bubble= pd.Series({1000 : 499500, 2000 : 1999000, 3000 : 4498500, 4000 : 7998000, 5000 : 12497500, 6000 : 17997000, 7000 : 24496500, 8000 : 31996000, 9000 : 40495500, 10000: 49995000, 25000: 312487500, 50000: 1249975000, 100000: 4999950000})
plt.plot(sort_bubble)
plt.title("число копирований в сортировке пузырьком")
plt.show()

# %%
sort_shell= pd.Series({1000 : 11716, 2000 : 26416, 3000 : 42714, 4000 : 58816, 5000 : 78798, 6000 : 94406, 7000 : 109444, 8000 : 129616, 9000 : 156200, 10000: 172578, 25000: 486165, 50000: 1047305, 100000: 2244585})
plt.plot(sort_shell)
plt.title("число сравнений в сортировке Шелла")
plt.show()

# %%
sort_shell= pd.Series({1000 : 4700, 2000 : 10400, 3000 : 15692, 4000 : 22800, 5000 : 28780, 6000 : 34384, 7000 : 39420, 8000 : 49600, 9000 : 57180, 10000: 62560, 25000: 186140, 50000: 397280, 100000: 844560})
plt.plot(sort_shell)
plt.title("число копирований в сортировке Шелла")
plt.show()

# %%
sort_pyramid= pd.Series({1000 : 10340, 2000 : 23784, 3000 : 38298, 4000 : 53557, 5000 : 69360, 6000 : 85378, 7000 : 101838, 8000 : 118984, 9000 : 136253, 10000: 153619, 25000: 434494, 50000: 939630, 100000: 2024810})
plt.plot(sort_pyramid)
plt.title("число сравнений в сортировке пирамидальной")
plt.show()

# %%
sort_pyramid= pd.Series({1000 : 8317, 2000 : 18709, 3000 : 29751, 4000 : 41437, 5000 : 53437, 6000 : 65599, 7000 : 78171, 8000 : 90777, 9000 : 103687, 10000: 116697, 25000: 326587, 50000: 698893, 100000: 1497435})
plt.plot(sort_pyramid)
plt.title("число копирований в сортировке пирамидальной")
plt.show()
